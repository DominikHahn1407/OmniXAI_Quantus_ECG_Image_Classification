# %%
import os

# %%
os.listdir("outputs/checkpoints")
# Out:
# ['vgg16_bn_best.pt',
#  'resnet101_best.pt',
#  'densenet169_best.pt',
#  'efficientnet_b1_best.pt',
#  'resnet34_best.pt',
#  'mobilenet_v2_best.pt',
#  'resnet18_best.pt',
#  'resnet50_best.pt',
#  'densenet121_best.pt',
#  'efficientnet_b0_best.pt']
